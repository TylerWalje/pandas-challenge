# %%
import pandas as pd
import numpy as np

# %%
file1 =("pandashomeworkfolder/purchase_data.csv")

# %%
purchasedata = pd.read_csv(file1)
purchasedata.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
players = len(purchasedata)
numberofplayers = pd.DataFrame([players], columns = ["Total Players"])
numberofplayers
# Out:
#    Total Players
# 0            780

# %%
averagepurchaseprice = purchasedata["Price"].mean()
averagepurchaseprice
# Out:
# 3.0509871794871795

# %%
numberofpurchases = len(purchasedata["Number Of Purchases"])
numberofpurchases
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\DU_DATA_SCIENCE\Anaconda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number Of Purchases'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
uniqueitems = file1["UniqueItems"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\DU_DATA_SCIENCE\Anaconda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unique'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-034efe18bdc5> in <module>
# ...
