# %%
import pandas as pd
import numpy as np
import os

# %%
file1 = os.path.join ("Desktop/pandas-challenge/purchase_data")

# %%
numberofplayers = len(file1)['SN'].unique()
pd.df({"Total Players: [number of players]"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-035233238654> in <module>
# ----> 1 numberofplayers = len(file1)['SN'].unique()
#       2 pd.df({"Total Players: [number of players]"})
#
# TypeError: 'int' object is not subscriptable
